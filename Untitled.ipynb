# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.corr().style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
#     #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow0_col1 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow0_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow1_col0 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f8aa15c4_e290_11ea_9661_a8a15916c3barow2_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
# ...

# %%
tips[:10].style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow0_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow1_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow1_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow1_col6 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c5b08cee_e28f_11ea_9661_a8a15916c3barow2_col0 {
#             background-color:  #2182b9;
#             color:  #000000;
# ...

# %%
sns.heatmap(tips.corr(), cmap='summer_r', annot=True)

# %%
sns.heatmap??
# Out:
# Signature:
# sns.heatmap(
#     data,
#     vmin=None,
#     vmax=None,
#     cmap=None,
#     center=None,
#     robust=False,
#     annot=None,
#     fmt='.2g',
#     annot_kws=None,
#     linewidths=0,
#     linecolor='white',
#     cbar=True,
#     cbar_kws=None,
#     cbar_ax=None,
#     square=False,
#     xticklabels='auto',
#     yticklabels='auto',
#     mask=None,
#     ax=None,
#     **kwargs,
# )
# Source:
# def heatmap(data, vmin=None, vmax=None, cmap=None, center=None, robust=False,
#             annot=None, fmt=".2g", annot_kws=None,
#             linewidths=0, linecolor="white",
#             cbar=True, cbar_kws=None, cbar_ax=None,
#             square=False, xticklabels="auto", yticklabels="auto",
#             mask=None, ax=None, **kwargs):
#     """Plot rectangular data as a color-encoded matrix.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
# ...
